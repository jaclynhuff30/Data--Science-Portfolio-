# %% [markdown]
# # Import Packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
from scipy.stats import boxcox

# %% [markdown]
# # Read In and View Data

# %%
cruise_ship = pd.read_excel('C:/Users/meredith.dodd/Documents/Data Science/105 Intermediate Statistics/Lesson 1/cruise_ship.xlsx')

# %%
pd.options.display.max_columns = None
cruise_ship.head()
# Out:
#           Ship      Line  YearBlt  Tonnage  passngrs  Length  Cabins  Crew  \
# 0      Journey   Azamara     2007    30277       694     594     355   355
# 1        Quest   Azamara     2007    30277       694     594     355   355
# 2  Celebration  Carnival     1987    47262      1486     722     743   670
# 3     Conquest  Carnival     2002   110000      2974     953    1488  1910
# 4      Destiny  Carnival     1996   101353      2642     892    1321  1000
#
#    PassSpcR  outcab
# 0     42.64     329
# 1     42.64     329
# 2     31.80     453
# 3     36.99     892
# 4     38.36     740

# %% [markdown]
# # Examine all Columns for Normality

# %%
sns.pairplot(cruise_ship)

# %% [markdown]
# # Transform Positively Skewed Data

# %% [markdown]
# ## Tonnage
# Use SQRT - log was too far over

# %%
cruise_ship['TonnageSQRT'] = np.sqrt(cruise_ship['Tonnage'])

# %%
cruise_ship.head()
# Out:
#           Ship      Line  YearBlt  Tonnage  passngrs  Length  Cabins  Crew  \
# 0      Journey   Azamara     2007    30277       694     594     355   355
# 1        Quest   Azamara     2007    30277       694     594     355   355
# 2  Celebration  Carnival     1987    47262      1486     722     743   670
# 3     Conquest  Carnival     2002   110000      2974     953    1488  1910
# 4      Destiny  Carnival     1996   101353      2642     892    1321  1000
#
#    PassSpcR  outcab  TonnageSQRT
# 0     42.64     329   174.002874
# 1     42.64     329   174.002874
# 2     31.80     453   217.398252
# 3     36.99     892   331.662479
# 4     38.36     740   318.359859

# %%
cruise_ship.TonnageSQRT.hist()

# %%
cruise_ship['TonnageLOG'] = np.log(cruise_ship['Tonnage'])

# %%
cruise_ship.head()
# Out:
#           Ship      Line  YearBlt  Tonnage  passngrs  Length  Cabins  Crew  \
# 0      Journey   Azamara     2007    30277       694     594     355   355
# 1        Quest   Azamara     2007    30277       694     594     355   355
# 2  Celebration  Carnival     1987    47262      1486     722     743   670
# 3     Conquest  Carnival     2002   110000      2974     953    1488  1910
# 4      Destiny  Carnival     1996   101353      2642     892    1321  1000
#
#    PassSpcR  outcab  TonnageSQRT  TonnageLOG
# 0     42.64     329   174.002874   10.318144
# 1     42.64     329   174.002874   10.318144
# 2     31.80     453   217.398252   10.763462
# 3     36.99     892   331.662479   11.608236
# 4     38.36     740   318.359859   11.526365

# %%
cruise_ship.TonnageLOG.hist()

# %% [markdown]
# ## Cabins

# %%
cruise_ship['CabinsSQRT'] = np.sqrt(cruise_ship['Cabins'])

# %%
cruise_ship.head()
# Out:
#           Ship      Line  YearBlt  Tonnage  passngrs  Length  Cabins  Crew  \
# 0      Journey   Azamara     2007    30277       694     594     355   355
# 1        Quest   Azamara     2007    30277       694     594     355   355
# 2  Celebration  Carnival     1987    47262      1486     722     743   670
# 3     Conquest  Carnival     2002   110000      2974     953    1488  1910
# 4      Destiny  Carnival     1996   101353      2642     892    1321  1000
#
#    PassSpcR  outcab  TonnageSQRT  TonnageLOG  CabinsSQRT
# 0     42.64     329   174.002874   10.318144   18.841444
# 1     42.64     329   174.002874   10.318144   18.841444
# 2     31.80     453   217.398252   10.763462   27.258026
# 3     36.99     892   331.662479   11.608236   38.574603
# 4     38.36     740   318.359859   11.526365   36.345564

# %%
cruise_ship.CabinsSQRT.hist()

# %% [markdown]
# ## Passengers

# %%
cruise_ship['passngrsSQRT'] = np.sqrt(cruise_ship['passngrs'])

# %%
cruise_ship.head()
# Out:
#           Ship      Line  YearBlt  Tonnage  passngrs  Length  Cabins  Crew  \
# 0      Journey   Azamara     2007    30277       694     594     355   355
# 1        Quest   Azamara     2007    30277       694     594     355   355
# 2  Celebration  Carnival     1987    47262      1486     722     743   670
# 3     Conquest  Carnival     2002   110000      2974     953    1488  1910
# 4      Destiny  Carnival     1996   101353      2642     892    1321  1000
#
#    PassSpcR  outcab  TonnageSQRT  TonnageLOG  CabinsSQRT  CabinsLOG  \
# 0     42.64     329   174.002874   10.318144   18.841444   5.872118
# 1     42.64     329   174.002874   10.318144   18.841444   5.872118
# 2     31.80     453   217.398252   10.763462   27.258026   6.610696
# 3     36.99     892   331.662479   11.608236   38.574603   7.305188
# 4     38.36     740   318.359859   11.526365   36.345564   7.186144
#
#    passngrsSQRT
# 0     26.343880
# 1     26.343880
# 2     38.548671
# 3     54.534393
# 4     51.400389

# %%
cruise_ship.passngrsSQRT.hist()

# %% [markdown]
# ## Crew

# %%
cruise_ship['CrewSQRT'] = np.sqrt(cruise_ship['Crew'])

# %%
cruise_ship.head()
# Out:
#           Ship      Line  YearBlt  Tonnage  passngrs  Length  Cabins  Crew  \
# 0      Journey   Azamara     2007    30277       694     594     355   355
# 1        Quest   Azamara     2007    30277       694     594     355   355
# 2  Celebration  Carnival     1987    47262      1486     722     743   670
# 3     Conquest  Carnival     2002   110000      2974     953    1488  1910
# 4      Destiny  Carnival     1996   101353      2642     892    1321  1000
#
#    PassSpcR  outcab  TonnageSQRT  TonnageLOG  CabinsSQRT  CabinsLOG  \
# 0     42.64     329   174.002874   10.318144   18.841444   5.872118
# 1     42.64     329   174.002874   10.318144   18.841444   5.872118
# 2     31.80     453   217.398252   10.763462   27.258026   6.610696
# 3     36.99     892   331.662479   11.608236   38.574603   7.305188
# 4     38.36     740   318.359859   11.526365   36.345564   7.186144
#
#    passngrsSQRT   CrewSQRT
# 0     26.343880  18.841444
# 1     26.343880  18.841444
# 2     38.548671  25.884358
# 3     54.534393  43.703547
# 4     51.400389  31.622777

# %%
cruise_ship.CrewSQRT.hist()

# %% [markdown]
# ## PassSpcR

# %%
cruise_ship['PassSpcRSQRT'] = np.sqrt(cruise_ship['PassSpcR'])

# %%
cruise_ship.head()
# Out:
#           Ship      Line  YearBlt  Tonnage  passngrs  Length  Cabins  Crew  \
# 0      Journey   Azamara     2007    30277       694     594     355   355
# 1        Quest   Azamara     2007    30277       694     594     355   355
# 2  Celebration  Carnival     1987    47262      1486     722     743   670
# 3     Conquest  Carnival     2002   110000      2974     953    1488  1910
# 4      Destiny  Carnival     1996   101353      2642     892    1321  1000
#
#    PassSpcR  outcab  TonnageSQRT  TonnageLOG  CabinsSQRT  CabinsLOG  \
# 0     42.64     329   174.002874   10.318144   18.841444   5.872118
# 1     42.64     329   174.002874   10.318144   18.841444   5.872118
# 2     31.80     453   217.398252   10.763462   27.258026   6.610696
# 3     36.99     892   331.662479   11.608236   38.574603   7.305188
# 4     38.36     740   318.359859   11.526365   36.345564   7.186144
#
#    passngrsSQRT   CrewSQRT  PassSpcRSQRT
# 0     26.343880  18.841444      6.529931
# 1     26.343880  18.841444      6.529931
# 2     38.548671  25.884358      5.639149
# 3     54.534393  43.703547      6.081940
# 4     51.400389  31.622777      6.193545

# %%
cruise_ship.PassSpcRSQRT.hist()

# %% [markdown]
# ## Outcab
# Use SQRT, log went too far

# %%
cruise_ship['outcabSQRT'] = np.sqrt(cruise_ship['outcab'])

# %%
cruise_ship.head()
# Out:
#           Ship      Line  YearBlt  Tonnage  passngrs  Length  Cabins  Crew  \
# 0      Journey   Azamara     2007    30277       694     594     355   355
# 1        Quest   Azamara     2007    30277       694     594     355   355
# 2  Celebration  Carnival     1987    47262      1486     722     743   670
# 3     Conquest  Carnival     2002   110000      2974     953    1488  1910
# 4      Destiny  Carnival     1996   101353      2642     892    1321  1000
#
#    PassSpcR  outcab  TonnageSQRT  TonnageLOG  CabinsSQRT  CabinsLOG  \
# 0     42.64     329   174.002874   10.318144   18.841444   5.872118
# 1     42.64     329   174.002874   10.318144   18.841444   5.872118
# 2     31.80     453   217.398252   10.763462   27.258026   6.610696
# 3     36.99     892   331.662479   11.608236   38.574603   7.305188
# 4     38.36     740   318.359859   11.526365   36.345564   7.186144
#
#    passngrsSQRT   CrewSQRT  PassSpcRSQRT  outcabSQRT
# 0     26.343880  18.841444      6.529931   18.138357
# 1     26.343880  18.841444      6.529931   18.138357
# 2     38.548671  25.884358      5.639149   21.283797
# 3     54.534393  43.703547      6.081940   29.866369
# 4     51.400389  31.622777      6.193545   27.202941

# %%
cruise_ship.outcabSQRT.hist()

# %%
cruise_ship['outcabLOG'] = np.log(cruise_ship['outcab'])

# %%
cruise_ship.head()
# Out:
#           Ship      Line  YearBlt  Tonnage  passngrs  Length  Cabins  Crew  \
# 0      Journey   Azamara     2007    30277       694     594     355   355
# 1        Quest   Azamara     2007    30277       694     594     355   355
# 2  Celebration  Carnival     1987    47262      1486     722     743   670
# 3     Conquest  Carnival     2002   110000      2974     953    1488  1910
# 4      Destiny  Carnival     1996   101353      2642     892    1321  1000
#
#    PassSpcR  outcab  TonnageSQRT  TonnageLOG  CabinsSQRT  CabinsLOG  \
# 0     42.64     329   174.002874   10.318144   18.841444   5.872118
# 1     42.64     329   174.002874   10.318144   18.841444   5.872118
# 2     31.80     453   217.398252   10.763462   27.258026   6.610696
# 3     36.99     892   331.662479   11.608236   38.574603   7.305188
# 4     38.36     740   318.359859   11.526365   36.345564   7.186144
#
#    passngrsSQRT   CrewSQRT  PassSpcRSQRT  outcabSQRT  outcabLOG
# 0     26.343880  18.841444      6.529931   18.138357   5.796058
# 1     26.343880  18.841444      6.529931   18.138357   5.796058
# 2     38.548671  25.884358      5.639149   21.283797   6.115892
# 3     54.534393  43.703547      6.081940   29.866369   6.793466
# 4     51.400389  31.622777      6.193545   27.202941   6.606650

# %%
cruise_ship.outcabLOG.hist()

# %% [markdown]
# # Transform Negatively Skewed Data

# %% [markdown]
# ## Year Built

# %%
cruise_ship['YearBltSQ'] = cruise_ship['YearBlt']**2

# %%
cruise_ship.head()
# Out:
#           Ship      Line  YearBlt  Tonnage  passngrs  Length  Cabins  Crew  \
# 0      Journey   Azamara     2007    30277       694     594     355   355
# 1        Quest   Azamara     2007    30277       694     594     355   355
# 2  Celebration  Carnival     1987    47262      1486     722     743   670
# 3     Conquest  Carnival     2002   110000      2974     953    1488  1910
# 4      Destiny  Carnival     1996   101353      2642     892    1321  1000
#
#    PassSpcR  outcab  TonnageSQRT  TonnageLOG  CabinsSQRT  CabinsLOG  \
# 0     42.64     329   174.002874   10.318144   18.841444   5.872118
# 1     42.64     329   174.002874   10.318144   18.841444   5.872118
# 2     31.80     453   217.398252   10.763462   27.258026   6.610696
# 3     36.99     892   331.662479   11.608236   38.574603   7.305188
# 4     38.36     740   318.359859   11.526365   36.345564   7.186144
#
#    passngrsSQRT   CrewSQRT  PassSpcRSQRT  outcabSQRT  outcabLOG  YearBltSQ
# 0     26.343880  18.841444      6.529931   18.138357   5.796058    4028049
# 1     26.343880  18.841444      6.529931   18.138357   5.796058    4028049
# 2     38.548671  25.884358      5.639149   21.283797   6.115892    3948169
# 3     54.534393  43.703547      6.081940   29.866369   6.793466    4008004
# 4     51.400389  31.622777      6.193545   27.202941   6.606650    3984016

# %%
cruise_ship.YearBltSQ.hist()

# %%
cruise_ship['YearBltCUBE'] = cruise_ship['YearBlt']**3

# %%
cruise_ship.head()
# Out:
#           Ship      Line  YearBlt  Tonnage  passngrs  Length  Cabins  Crew  \
# 0      Journey   Azamara     2007    30277       694     594     355   355
# 1        Quest   Azamara     2007    30277       694     594     355   355
# 2  Celebration  Carnival     1987    47262      1486     722     743   670
# 3     Conquest  Carnival     2002   110000      2974     953    1488  1910
# 4      Destiny  Carnival     1996   101353      2642     892    1321  1000
#
#    PassSpcR  outcab  TonnageSQRT  TonnageLOG  CabinsSQRT  CabinsLOG  \
# 0     42.64     329   174.002874   10.318144   18.841444   5.872118
# 1     42.64     329   174.002874   10.318144   18.841444   5.872118
# 2     31.80     453   217.398252   10.763462   27.258026   6.610696
# 3     36.99     892   331.662479   11.608236   38.574603   7.305188
# 4     38.36     740   318.359859   11.526365   36.345564   7.186144
#
#    passngrsSQRT   CrewSQRT  PassSpcRSQRT  outcabSQRT  outcabLOG  YearBltSQ  \
# 0     26.343880  18.841444      6.529931   18.138357   5.796058    4028049
# 1     26.343880  18.841444      6.529931   18.138357   5.796058    4028049
# 2     38.548671  25.884358      5.639149   21.283797   6.115892    3948169
# 3     54.534393  43.703547      6.081940   29.866369   6.793466    4008004
# 4     51.400389  31.622777      6.193545   27.202941   6.606650    3984016
#
#    YearBltCUBE
# 0   8084294343
# 1   8084294343
# 2   7845011803
# 3   8024024008
# 4   7952095936

# %%
cruise_ship.YearBltCUBE.hist()

# %% [markdown]
# ## Length
# Go with square, cube takes it too far

# %%
cruise_ship['LengthSQ'] = cruise_ship['Length']**2

# %%
cruise_ship.head()
# Out:
#           Ship      Line  YearBlt  Tonnage  passngrs  Length  Cabins  Crew  \
# 0      Journey   Azamara     2007    30277       694     594     355   355
# 1        Quest   Azamara     2007    30277       694     594     355   355
# 2  Celebration  Carnival     1987    47262      1486     722     743   670
# 3     Conquest  Carnival     2002   110000      2974     953    1488  1910
# 4      Destiny  Carnival     1996   101353      2642     892    1321  1000
#
#    PassSpcR  outcab  TonnageSQRT  TonnageLOG  CabinsSQRT  CabinsLOG  \
# 0     42.64     329   174.002874   10.318144   18.841444   5.872118
# 1     42.64     329   174.002874   10.318144   18.841444   5.872118
# 2     31.80     453   217.398252   10.763462   27.258026   6.610696
# 3     36.99     892   331.662479   11.608236   38.574603   7.305188
# 4     38.36     740   318.359859   11.526365   36.345564   7.186144
#
#    passngrsSQRT   CrewSQRT  PassSpcRSQRT  outcabSQRT  outcabLOG  YearBltSQ  \
# 0     26.343880  18.841444      6.529931   18.138357   5.796058    4028049
# 1     26.343880  18.841444      6.529931   18.138357   5.796058    4028049
# 2     38.548671  25.884358      5.639149   21.283797   6.115892    3948169
# 3     54.534393  43.703547      6.081940   29.866369   6.793466    4008004
# 4     51.400389  31.622777      6.193545   27.202941   6.606650    3984016
#
#    YearBltCUBE  LengthSQ
# 0   8084294343    352836
# 1   8084294343    352836
# 2   7845011803    521284
# 3   8024024008    908209
# 4   7952095936    795664

# %%
cruise_ship.LengthSQ.hist()

# %%
cruise_ship['LengthCUBE'] = cruise_ship['Length']**3

# %%
cruise_ship.head()
# Out:
#           Ship      Line  YearBlt  Tonnage  passngrs  Length  Cabins  Crew  \
# 0      Journey   Azamara     2007    30277       694     594     355   355
# 1        Quest   Azamara     2007    30277       694     594     355   355
# 2  Celebration  Carnival     1987    47262      1486     722     743   670
# 3     Conquest  Carnival     2002   110000      2974     953    1488  1910
# 4      Destiny  Carnival     1996   101353      2642     892    1321  1000
#
#    PassSpcR  outcab  TonnageSQRT  TonnageLOG  CabinsSQRT  CabinsLOG  \
# 0     42.64     329   174.002874   10.318144   18.841444   5.872118
# 1     42.64     329   174.002874   10.318144   18.841444   5.872118
# 2     31.80     453   217.398252   10.763462   27.258026   6.610696
# 3     36.99     892   331.662479   11.608236   38.574603   7.305188
# 4     38.36     740   318.359859   11.526365   36.345564   7.186144
#
#    passngrsSQRT   CrewSQRT  PassSpcRSQRT  outcabSQRT  outcabLOG  YearBltSQ  \
# 0     26.343880  18.841444      6.529931   18.138357   5.796058    4028049
# 1     26.343880  18.841444      6.529931   18.138357   5.796058    4028049
# 2     38.548671  25.884358      5.639149   21.283797   6.115892    3948169
# 3     54.534393  43.703547      6.081940   29.866369   6.793466    4008004
# 4     51.400389  31.622777      6.193545   27.202941   6.606650    3984016
#
#    YearBltCUBE  LengthSQ  LengthCUBE
# 0   8084294343    352836   209584584
# 1   8084294343    352836   209584584
# 2   7845011803    521284   376367048
# 3   8024024008    908209   865523177
# 4   7952095936    795664   709732288

# %%
cruise_ship.LengthCUBE.hist()
